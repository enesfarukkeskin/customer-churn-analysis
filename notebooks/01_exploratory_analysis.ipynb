# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from src.data.data_processor import DataProcessor
from src.visualization.visualizer import Visualizer

# %%
processor = DataProcessor(
    input_path="/Users/enes/Downloads/teknasyon-case-ai-datascientist/challenge/Customer Churn Analysis/data/raw/churn_train.csv",
    output_path="/Users/enes/Downloads/teknasyon-case-ai-datascientist/challenge/Customer Churn Analysis/data/processed/churn_train_processed.csv"
)
processed_data = processor.process()
# Out:
# INFO:src.data.data_processor:Starting data processing pipeline
# INFO:src.data.data_processor:Loading data from /Users/enes/Downloads/teknasyon-case-ai-datascientist/challenge/Customer Churn Analysis/data/raw/churn_train.csv
# INFO:src.data.data_processor:Data loaded successfully. Shape: (60000, 66)
# INFO:src.data.data_processor:Removed 0 duplicate rows
# INFO:src.data.data_processor:Handling missing values
# INFO:src.data.data_processor:Missing values handled successfully
# INFO:src.data.data_processor:Handling outliers using iqr method
# INFO:src.data.data_processor:Data saved successfully to /Users/enes/Downloads/teknasyon-case-ai-datascientist/challenge/Customer Churn Analysis/data/processed/churn_train_processed.csv
# INFO:src.data.data_processor:Data processing completed successfully

# %%
visualizer = Visualizer(processed_data)

# %%
important_features = [
    'user_lifetime',
    'user_spendings',
    'calls_outgoing_count',
    'sms_outgoing_count',
    'gprs_usage'
]

# %%
visualizer.plot_feature_distributions(important_features)
# Out:
# /Users/enes/anaconda3/envs/sms-span/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/enes/anaconda3/envs/sms-span/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/enes/anaconda3/envs/sms-span/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
visualizer.plot_correlation_matrix(important_features)
